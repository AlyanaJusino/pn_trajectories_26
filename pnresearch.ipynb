# %% [markdown]
# print('hello world')

# %% [markdown]
# # 1d

# %%
import numpy as np

# %%
N = 100
t = np.linspace(0,1,N)
y = np.zeros(N)

y0 = 10
y[0] = y0

# %%
def f(y,t):
    return 0.1

# %%
def solve(y,t,f): 
    for n in range(1, len(t)):
        y[n]= y[n-1] + (t[n] - t[n-1]) * f(y[n-1], t[n-1]);

    return None

# %%
N = 100
t = np.linspace(0,1,N)

def setup_and_solve(y0, f,t):
    y = np.zeros(len(t))
    y[0] = y0; 

    solve(y,t,f)
    return y

# %%
y = setup_and_solve(t=t, y0=0.01, f=f)

# %%
y
# Out:
# array([0.01      , 0.0110101 , 0.0120202 , 0.0130303 , 0.0140404 ,
#        0.01505051, 0.01606061, 0.01707071, 0.01808081, 0.01909091,
#        0.02010101, 0.02111111, 0.02212121, 0.02313131, 0.02414141,
#        0.02515152, 0.02616162, 0.02717172, 0.02818182, 0.02919192,
#        0.03020202, 0.03121212, 0.03222222, 0.03323232, 0.03424242,
#        0.03525253, 0.03626263, 0.03727273, 0.03828283, 0.03929293,
#        0.04030303, 0.04131313, 0.04232323, 0.04333333, 0.04434343,
#        0.04535354, 0.04636364, 0.04737374, 0.04838384, 0.04939394,
#        0.05040404, 0.05141414, 0.05242424, 0.05343434, 0.05444444,
#        0.05545455, 0.05646465, 0.05747475, 0.05848485, 0.05949495,
#        0.06050505, 0.06151515, 0.06252525, 0.06353535, 0.06454545,
#        0.06555556, 0.06656566, 0.06757576, 0.06858586, 0.06959596,
#        0.07060606, 0.07161616, 0.07262626, 0.07363636, 0.07464646,
#        0.07565657, 0.07666667, 0.07767677, 0.07868687, 0.07969697,
#        0.08070707, 0.08171717, 0.08272727, 0.08373737, 0.08474747,
#        0.08575758, 0.08676768, 0.08777778, 0.08878788, 0.08979798,
#        0.09080808, 0.09181818, 0.09282828, 0.09383838, 0.09484848,
#        0.09585859, 0.09686869, 0.09787879, 0.09888889, 0.09989899,
#        0.10090909, 0.10191919, 0.10292929, 0.10393939, 0.10494949,
#        0.1059596 , 0.1069697 , 0.1079798 , 0.1089899 , 0.11      ])

# %% [markdown]
# # 2nd order

# %%
def f(y,t): 
    return 0.1 + y * 0.05

# %%
def solve(y,t,f): 
    for n in range(1, len(t)):
        y[:,n]= y[:,n-1] + (t[n] - t[n-1]) * f(y[:,n-1], t[n-1]);

    return None

# %%
def setup_and_solve(y0, f,t):
    y = np.zeros((len(y0),len(t)))
    y[:,0] = y0; 

    solve(y,t,f)
    return y

# %%
y = setup_and_solve(t=t, y0=np.array([0.0,0.1]), f=f)

# %%
y
# Out:
# array([[0.        , 0.0010101 , 0.00202071, 0.00303183, 0.00404347,
#         0.00505561, 0.00606826, 0.00708143, 0.00809511, 0.0091093 ,
#         0.010124  , 0.01113921, 0.01215494, 0.01317118, 0.01418793,
#         0.0152052 , 0.01622298, 0.01724127, 0.01826008, 0.01927941,
#         0.02029924, 0.0213196 , 0.02234047, 0.02336185, 0.02438375,
#         0.02540617, 0.0264291 , 0.02745255, 0.02847651, 0.029501  ,
#         0.030526  , 0.03155151, 0.03257755, 0.0336041 , 0.03463118,
#         0.03565877, 0.03668688, 0.03771551, 0.03874466, 0.03977433,
#        0.05113507, 0.05217099, 0.05320744, 0.05424442, 0.05528191,
#        0.05631994, 0.05735848, 0.05839755, 0.05943715, 0.06047727,
#        0.06151791, 0.06255908, 0.06360078, 0.064643  , 0.06568575,
#        0.06672902, 0.06777283, 0.06881716, 0.06986201, 0.0709074 ,
#        0.07195331, 0.07299975, 0.07404672, 0.07509422, 0.07614225,
#        0.0771908 , 0.07823989, 0.07928951, 0.08033965, 0.08139033,
#        0.08244154, 0.08349328, 0.08454554, 0.08559835, 0.08665168,
#        0.08770554, 0.08875994, 0.08981487, 0.09087033, 0.09192633,
#        0.09298285, 0.09403992, 0.09509751, 0.09615564, 0.09721431,
#        0.09827351, 0.09933324, 0.10039351, 0.10145431, 0.10251565])

# %% [raw]
# * plot these into graphs, (position v time)
# * dy/dt - play with different functional forms of it to see what

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t,y[0,:]) #using specifically y[0,:] to give a specific position w the corresponding time values
#also the x and y should have the same dimensions, since y has a larger dimension, it wouldn't match time's

plt.xlabel("Position") #labels (bc yes)
plt.ylabel("TIme")
plt.title("Position v. Time")

plt.grid() #because grid lines look nice sometimes
plt.show()

# %% [markdown]
# # ASSIGNMENT
# - CODE FOR A SPRING X** = -X
# - CURVE OF POSITION AS A FUNCTION OF TIME
# - CURVE OF VELOCITY AS A FUNCTION OF TIME

# %%
#start of our spring equation 
def spring_eq(y,t): 
    return np.array([y[1], -y[0]]) #this is the vectors of the position and velocity
    #y(0) is position
    #y(1) is velocity

# %%
N = 5000 #how many steps or points it takes
y0 = np.array([1.0, 0.0]) #initial, position 1 is 

t = np.linspace(0,20,N) #start at 0 seconds and end at 20 seconds 

y = setup_and_solve(y0=y0, t=t, f=spring_eq) #change f to f = spring_eq to call 
#back to the function

# %%
plt.plot(t, y[0])

plt.xlabel("Time")
plt.ylabel("Position")
plt.title("Position v. Time")

plt.grid() #because grid lines look nice sometimes
plt.show()

# %%
plt.plot(t, y[1])
plt.xlabel("Time")
plt.ylabel("Velocity")
plt.title("Velocity v. Time")

plt.grid() #because grid lines look nice sometimes
plt.show()

# %%
fig, ax = plt.subplots() #making the overlay

#overlaying the plots 
ax.plot(t, y[1], label='Velocity', color='red') 
ax.plot(t,y[0], label='Position', color='blue')
ax.set_title('Overlay Plots')
ax.legend()
ax.grid(True)

# %% [markdown]
# ### redoing it with the damping (?) force
# - so x** = -x*-0.01v

# %%
#start of our spring equation (damp) 
def spring_eq(y,t): 
    return np.array([y[1], -y[0] - 0.2 * y[1]]) #this is the vectors of the position and velocity
    #y(0) is position
    #y(1) is velocity 
    # now including the damping force of the equation , play with the -0.01, making it -1.00 cancels it

# %%
N = 1000 #how many steps or points it takes

y0 = np.array([1.0, 0.0]) #initial, position 1 is 

t = np.linspace(0,20,N) #start at 0 seconds and end at 20 seconds 

y = setup_and_solve(y0=y0, t=t, f=spring_eq) #change f to f = spring_eq to call 
#back to the function

# %%
plt.plot(t, y[0], label="Position")
plt.plot(t, y[1], label="Velocity")
plt.xlabel("Time")
plt.ylabel("Position / Velocity")
plt.title("Damped Spring")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(t, y[0])

plt.xlabel("Time")
plt.ylabel("Position")
plt.title("Position v. Time")

plt.grid() #because grid lines look nice sometimes
plt.show()
